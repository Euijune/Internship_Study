# %% [markdown]
# ### Ideas taken from:
#
# Knowledge Distillation  Explained with Keras Example | #MLConcepts
# (https://www.youtube.com/watch?v=0ZS2lLsZwBY)
#
# https://keras.io/examples/vision/knowledge_distillation/
#
# https://github.com/keras-team/keras-io/blob/master/examples/vision/knowledge_distillation.py
#
#
# Knowledge Distillation - Keras Code Examples | Henry AI Labs
# (https://www.youtube.com/watch?v=Y2K13XDqwiM)
# (https://www.youtube.com/watch?v=gZPUGje1PCI)
#
#
#
# #### TODO:
#
# https://huggingface.co/docs/transformers/model_doc/distilbert

# %% [markdown]
# ### Main idea:
#
# Knowledge Distillation is a procedure for model compression, in which a small (student) model is trained to match a large pre-trained (teacher) model.
#
# Knowledge is transferred from the teacher model to the student by minimizing a loss function, aimed at matching softened teacher logits as well as ground-truth labels.

# %% [markdown]
# ### Distiller
#
# The custom Distiller() class, overrides the Model methods train_step, test_step, and compile(). In order to use the distiller, we need:
#
# 1: Define and train a teacher model - This is a large convnet model for image classification.
#
# 2: Define a student model to train - This is a smaller convnet model for image classification.
#
# A student loss function on the difference between student predictions and ground-truth
#
# A distillation loss function, along with a temperature, on the difference between the soft student predictions and the soft teacher labels
#
# An alpha factor to weight the student and distillation loss
#
# An optimizer for the student and (optional) metrics to evaluate performance
#
# In the train_step method, we perform a forward pass of both the teacher and student, calculate the loss with weighting of the student_loss and distillation_loss by alpha and 1 - alpha, respectively, and perform the backward pass. Note: only the student weights are updated, and therefore we only calculate the gradients for the student weights.
#
# In the test_step method, we evaluate the student model on the provided dataset.

# %% [markdown]
# ### Code starts here

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %% [markdown]
# ## Create student and teacher models
#
# Initialy, we create a teacher model and a smaller student model. Both models are
# convolutional neural networks and created using `Sequential()`,
# but could be any Keras model.
#
#
# Q: Why the original teacher (v1) model not use the softmax activation - https://github.com/keras-team/keras-io/issues/755 ?
#
# https://datascience.stackexchange.com/questions/73093/what-does-from-logits-true-do-in-sparsecategoricalcrossentropy-loss-function
#
#
# The from_logits=True attribute inform the loss function that the output values generated by the model are not normalized, a.k.a. logits.
# In other words, the softmax function has not been applied on them to produce a probability distribution. Therefore, the output layer in this case does not have a softmax activation function:
#
# so basically what it means is if softmax layer is not being added at the last layer then we need to have the from_logits=True to indicate the probabilities are not normalized

# %% [markdown]
# SparseCategoricalCrossentropy 에 softmax함수가 포함되어 있음
#
#
# > https://guru.tistory.com/67

# %%
def make_teacher_model(version='v3'):
    if version == 'v1':
        # Create the teacher
        teacher = keras.Sequential(
            [
                keras.Input(shape=(32, 32, 3)),
                layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Conv2D(512, (3, 3), strides=(2, 2), padding="same"),
                layers.Flatten(),
                layers.Dense(10),
            ],
            name="teacher",
        )

    if version == 'v2':
        # add multiple conv blocks
        teacher = keras.Sequential(
            [
                keras.Input(shape=(32, 32, 3)),
                layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Conv2D(512, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Flatten(),
                layers.Dense(128, activation='relu'),
                layers.Dense(10),
            ],
            name="teacher",
        )
        
    if version == 'v3':
        # add dropout
        teacher = keras.Sequential(
            [
                keras.Input(shape=(32, 32, 3)),
                layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Dropout(0.2),
                layers.Conv2D(256, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Dropout(0.3),
                layers.Conv2D(512, (3, 3), strides=(2, 2), padding="same"),
                layers.LeakyReLU(alpha=0.2),
                layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
                layers.Dropout(0.4),
                layers.Flatten(),
                layers.Dense(128, activation='relu'),
                layers.Dropout(0.5),
                layers.Dense(10),
            ],
            name="teacher",
        )

    return teacher

# %%
# teacher = make_teacher_model(version='v2')
teacher = make_teacher_model(version='v3')

# %% [markdown]
# ## Prepare the dataset
#
# Possible datasets:
#
# [MNIST](https://keras.io/api/datasets/mnist/),
#
# (Not used )
#
# ---------
#
# [CIFAR-10](https://keras.io/api/datasets/cifar10/)
#
# This is a dataset of 50,000 32x32 color training images and 10,000 test images, labeled over 10 categories.
#
# https://www.cs.toronto.edu/~kriz/cifar.html
#
# The classes are completely mutually exclusive. There is no overlap between automobiles and trucks. "Automobile" includes sedans, SUVs, things of that sort. "Truck" includes only big trucks. Neither includes pickup trucks.
#
# Pixel values range from 0 to 255.
#
#
# Both the student and teacher are trained on the training set and evaluated on
# the test set.

# %%
# Prepare the train and test dataset.
batch_size = 64
# (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
x_test.shape, y_test.shape
# Out:
# ((10000, 32, 32, 3), (10000, 1))

# %%
y_train[0]
# Out:
# array([6], dtype=uint8)

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
# Normalize data
x_train = x_train.astype("float32") / 255.0
x_train = np.reshape(x_train, (-1, 32, 32, 3))

x_test = x_test.astype("float32") / 255.0
x_test = np.reshape(x_test, (-1, 32, 32, 3))

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
x_train[0]
# Out:
# array([[[0.23137255, 0.24313726, 0.24705882],
#         [0.16862746, 0.18039216, 0.1764706 ],
#         [0.19607843, 0.1882353 , 0.16862746],
#         ...,
#         [0.61960787, 0.5176471 , 0.42352942],
#         [0.59607846, 0.49019608, 0.4       ],
#         [0.5803922 , 0.4862745 , 0.40392157]],
#
#        [[0.0627451 , 0.07843138, 0.07843138],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509805, 0.21568628],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117648, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215687, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941177, 0.19607843],
#         [0.47058824, 0.32941177, 0.19607843],
#         [0.42745098, 0.28627452, 0.16470589]],
#
#        ...,
#
#        [[0.8156863 , 0.6666667 , 0.3764706 ],
#         [0.7882353 , 0.6       , 0.13333334],
#         [0.7764706 , 0.6313726 , 0.10196079],
#         ...,
#         [0.627451  , 0.52156866, 0.27450982],
#         [0.21960784, 0.12156863, 0.02745098],
#         [0.20784314, 0.13333334, 0.07843138]],
#
#        [[0.7058824 , 0.54509807, 0.3764706 ],
#         [0.6784314 , 0.48235294, 0.16470589],
#         [0.7294118 , 0.5647059 , 0.11764706],
#         ...,
#         [0.72156864, 0.5803922 , 0.36862746],
#         [0.38039216, 0.24313726, 0.13333334],
#         [0.3254902 , 0.20784314, 0.13333334]],
#
#        [[0.69411767, 0.5647059 , 0.45490196],
#         [0.65882355, 0.5058824 , 0.36862746],
#         [0.7019608 , 0.5568628 , 0.34117648],
#         ...,
#         [0.84705883, 0.72156864, 0.54901963],
#         [0.5921569 , 0.4627451 , 0.32941177],
#         [0.48235294, 0.36078432, 0.28235295]]], dtype=float32)

# %% [markdown]
# ## Train the teacher
# In knowledge distillation we assume that the teacher is trained and fixed. Thus, we start
# by training the teacher model on the training set in the usual way.
#
#
# ### Model params:
# https://stackoverflow.com/questions/44477489/keras-difference-between-categorical-accuracy-and-sparse-categorical-accuracy
#
# in categorical_accuracy you need to specify your target (y) as one-hot encoded vector (e.g. in case of 3 classes, when a true class is second class, y should be (0, 1, 0).
#
# In sparse_categorical_accuracy you need should only provide an integer of the true class (in the case from previous example - it would be 1 as classes indexing is 0-based).
#
#
# ### Improve the teacher model:
#
# https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/
#
#
# It is better to use a separate validation dataset, e.g. by splitting the train dataset into train and validation sets. We will not split the data in this case, and instead use the test dataset as a validation dataset to keep the example simple.
#
# using multi layers of conv2d+maxpool helps >5% - against 1 block
#
# https://stackoverflow.com/questions/63989328/can-i-combine-conv2d-and-leakyrelu-into-a-single-layer
#
# adding Leakyrelu after conv2d helped: around 4% boost
#
# adding dropout - reduces the rate/extent of overfitting

# %%
# Train teacher as usual
teacher.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)

# %% [markdown]
# SparseCategoricalCrossentropy
#
# > https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy

# %%
# Train and evaluate teacher on data.
history  = teacher.fit(x_train, 
            y_train, 
            epochs=20,
            batch_size=batch_size,
            validation_data=(x_test, y_test), 
            verbose=1)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 725s 926ms/step - loss: 1.7221 - sparse_categorical_accuracy: 0.3643 - val_loss: 1.3504 - val_sparse_categorical_accuracy: 0.5140
# Epoch 2/20
# 782/782 [==============================] - 659s 843ms/step - loss: 1.3571 - sparse_categorical_accuracy: 0.5122 - val_loss: 1.1231 - val_sparse_categorical_accuracy: 0.5955
# Epoch 3/20
# 782/782 [==============================] - 656s 838ms/step - loss: 1.2135 - sparse_categorical_accuracy: 0.5691 - val_loss: 1.0692 - val_sparse_categorical_accuracy: 0.6132
# Epoch 4/20
# 782/782 [==============================] - 650s 831ms/step - loss: 1.1035 - sparse_categorical_accuracy: 0.6126 - val_loss: 1.0112 - val_sparse_categorical_accuracy: 0.6482
# Epoch 5/20
# 782/782 [==============================] - 653s 835ms/step - loss: 1.0443 - sparse_categorical_accuracy: 0.6302 - val_loss: 0.9601 - val_sparse_categorical_accuracy: 0.6675
# Epoch 6/20
# 782/782 [==============================] - 651s 833ms/step - loss: 0.9959 - sparse_categorical_accuracy: 0.6518 - val_loss: 0.9296 - val_sparse_categorical_accuracy: 0.6684
# Epoch 7/20
# 782/782 [==============================] - 650s 831ms/step - loss: 0.9385 - sparse_categorical_accuracy: 0.6690 - val_loss: 0.8683 - val_sparse_categorical_accuracy: 0.6970
# Epoch 8/20
# 782/782 [==============================] - 652s 834ms/step - loss: 0.8954 - sparse_categorical_accuracy: 0.6865 - val_loss: 0.8187 - val_sparse_categorical_accuracy: 0.7187
# Epoch 9/20
# 782/782 [==============================] - 655s 838ms/step - loss: 0.8706 - sparse_categorical_accuracy: 0.6963 - val_loss: 0.8396 - val_sparse_categorical_accuracy: 0.7103
# Epoch 10/20
# 782/782 [==============================] - 655s 837ms/step - loss: 0.8366 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.8739 - val_sparse_categorical_accuracy: 0.7008
# Epoch 11/20
# 782/782 [==============================] - 654s 837ms/step - loss: 0.8172 - sparse_categorical_accuracy: 0.7157 - val_loss: 0.7752 - val_sparse_categorical_accuracy: 0.7346
# Epoch 12/20
# 782/782 [==============================] - 653s 835ms/step - loss: 0.7816 - sparse_categorical_accuracy: 0.7309 - val_loss: 0.7336 - val_sparse_categorical_accuracy: 0.7513
# Epoch 13/20
# 782/782 [==============================] - 656s 838ms/step - loss: 0.7686 - sparse_categorical_accuracy: 0.7342 - val_loss: 0.7931 - val_sparse_categorical_accuracy: 0.7246
# Epoch 14/20
# 782/782 [==============================] - 654s 836ms/step - loss: 0.7545 - sparse_categorical_accuracy: 0.7393 - val_loss: 0.8392 - val_sparse_categorical_accuracy: 0.7213
# Epoch 15/20
# 782/782 [==============================] - 651s 832ms/step - loss: 0.7346 - sparse_categorical_accuracy: 0.7442 - val_loss: 0.8210 - val_sparse_categorical_accuracy: 0.7387
# Epoch 16/20
# 782/782 [==============================] - 651s 833ms/step - loss: 0.7179 - sparse_categorical_accuracy: 0.7504 - val_loss: 0.7411 - val_sparse_categorical_accuracy: 0.7545
# Epoch 17/20
# 782/782 [==============================] - 651s 832ms/step - loss: 0.7047 - sparse_categorical_accuracy: 0.7577 - val_loss: 0.7367 - val_sparse_categorical_accuracy: 0.7592
# Epoch 18/20
# 782/782 [==============================] - 653s 834ms/step - loss: 0.6842 - sparse_categorical_accuracy: 0.7633 - val_loss: 0.7723 - val_sparse_categorical_accuracy: 0.7471
# Epoch 19/20
# 782/782 [==============================] - 651s 832ms/step - loss: 0.6819 - sparse_categorical_accuracy: 0.7652 - val_loss: 0.7340 - val_sparse_categorical_accuracy: 0.7616
# Epoch 20/20
# 782/782 [==============================] - 669s 856ms/step - loss: 0.6715 - sparse_categorical_accuracy: 0.7709 - val_loss: 0.8161 - val_sparse_categorical_accuracy: 0.7482

# %%
teacher.evaluate(x_test, y_test)
print(teacher.metrics_names)
# Out:
# 313/313 [==============================] - 25s 81ms/step - loss: 0.8161 - sparse_categorical_accuracy: 0.7482
# ['loss', 'sparse_categorical_accuracy']

# %% [markdown]
# Model training APIs
#
#
# > https://keras.io/api/models/model_training_apis/

# %% [markdown]
# ### Next task:
#
# ## Train student from scratch for comparison
#
# define student
#
# train student without distillation (student_scratch)
#
#
# We can also train an equivalent student model from scratch without the teacher, in order
# to evaluate the performance gain obtained by knowledge distillation.

# %%
# Create the student
student_scratch = keras.Sequential(
    [
        keras.Input(shape=(32, 32, 3)),
        layers.Conv2D(32, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
        layers.Conv2D(32, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(16, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10),
    ],
    name="student_scratch",
)

# %%
# Train student as doen usually
student_scratch.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)

# %%
# Train and evaluate student trained from scratch.
history2 = student_scratch.fit(x_train, 
                               y_train, 
                               epochs=20,
                                batch_size=batch_size,
                                validation_data=(x_test, y_test), 
                                verbose=1)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 38s 48ms/step - loss: 1.9307 - sparse_categorical_accuracy: 0.2754 - val_loss: 1.5638 - val_sparse_categorical_accuracy: 0.4514
# Epoch 2/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.7079 - sparse_categorical_accuracy: 0.3608 - val_loss: 1.4610 - val_sparse_categorical_accuracy: 0.5105
# Epoch 3/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.5971 - sparse_categorical_accuracy: 0.4016 - val_loss: 1.3266 - val_sparse_categorical_accuracy: 0.5388
# Epoch 4/20
# 782/782 [==============================] - 32s 42ms/step - loss: 1.5415 - sparse_categorical_accuracy: 0.4262 - val_loss: 1.2803 - val_sparse_categorical_accuracy: 0.5659
# Epoch 5/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.5115 - sparse_categorical_accuracy: 0.4372 - val_loss: 1.2865 - val_sparse_categorical_accuracy: 0.5574
# Epoch 6/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4775 - sparse_categorical_accuracy: 0.4497 - val_loss: 1.2099 - val_sparse_categorical_accuracy: 0.5842
# Epoch 7/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4543 - sparse_categorical_accuracy: 0.4588 - val_loss: 1.1761 - val_sparse_categorical_accuracy: 0.5986
# Epoch 8/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4464 - sparse_categorical_accuracy: 0.4609 - val_loss: 1.1940 - val_sparse_categorical_accuracy: 0.5923
# Epoch 9/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4241 - sparse_categorical_accuracy: 0.4688 - val_loss: 1.1506 - val_sparse_categorical_accuracy: 0.6111
# Epoch 10/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4111 - sparse_categorical_accuracy: 0.4731 - val_loss: 1.1318 - val_sparse_categorical_accuracy: 0.6149
# Epoch 11/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4039 - sparse_categorical_accuracy: 0.4760 - val_loss: 1.1397 - val_sparse_categorical_accuracy: 0.6108
# Epoch 12/20
# 782/782 [==============================] - 34s 43ms/step - loss: 1.3894 - sparse_categorical_accuracy: 0.4812 - val_loss: 1.1204 - val_sparse_categorical_accuracy: 0.6175
# Epoch 13/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.3822 - sparse_categorical_accuracy: 0.4836 - val_loss: 1.1443 - val_sparse_categorical_accuracy: 0.6094
# Epoch 14/20
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3651 - sparse_categorical_accuracy: 0.4901 - val_loss: 1.1078 - val_sparse_categorical_accuracy: 0.6215
# Epoch 15/20
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3637 - sparse_categorical_accuracy: 0.4884 - val_loss: 1.1233 - val_sparse_categorical_accuracy: 0.6076
# Epoch 16/20
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3584 - sparse_categorical_accuracy: 0.4914 - val_loss: 1.0863 - val_sparse_categorical_accuracy: 0.6295
# Epoch 17/20
# 782/782 [==============================] - 34s 43ms/step - loss: 1.3507 - sparse_categorical_accuracy: 0.4938 - val_loss: 1.0969 - val_sparse_categorical_accuracy: 0.6297
# Epoch 18/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.3524 - sparse_categorical_accuracy: 0.4961 - val_loss: 1.1161 - val_sparse_categorical_accuracy: 0.6257
# Epoch 19/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.3427 - sparse_categorical_accuracy: 0.4991 - val_loss: 1.0850 - val_sparse_categorical_accuracy: 0.6312
# Epoch 20/20
# 782/782 [==============================] - 32s 41ms/step - loss: 1.3399 - sparse_categorical_accuracy: 0.4967 - val_loss: 1.0749 - val_sparse_categorical_accuracy: 0.6365

# %%
student_scratch.evaluate(x_test, y_test)
print(student_scratch.metrics_names)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 1.0749 - sparse_categorical_accuracy: 0.6365
# ['loss', 'sparse_categorical_accuracy']

# %% [markdown]
# ### student_scratch best perf =
#
# 63%

# %% [markdown]
# ### Next task:
#
# train student with distillation
#
# can this increase the score for student?

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):
        """ Configure the distiller.
        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)
            distillation_loss = self.distillation_loss_fn(
                tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                tf.nn.softmax(student_predictions / self.temperature, axis=1),
            )
            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %% [markdown]
# GradientTape
#
#
# > https://shinslab.tistory.com/110

# %%
# Create the student
student = keras.Sequential(
    [
        keras.Input(shape=(32, 32, 3)),
        layers.Conv2D(32, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
        layers.Conv2D(32, (3, 3), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding="same"),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(16, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10),
    ],
    name="student",
)

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)

# %%
distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)

# %% [markdown]
# KL Divergence
#
# > https://angeloyeo.github.io/2020/10/27/KL_divergence.html

# %% [markdown]
# KLDivergence 와 CrossEntropy
#
#
# > https://uhou.tistory.com/200

# %%
# Distill teacher to student
history3 = distiller.fit(x_train, 
                         y_train, 
                         epochs=20,
                         batch_size=batch_size,
                         validation_data=(x_test, y_test), 
                         verbose=1)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 154s 196ms/step - sparse_categorical_accuracy: 0.2655 - student_loss: 2.0012 - distillation_loss: 0.2400 - val_sparse_categorical_accuracy: 0.4435 - val_student_loss: 1.7149
# Epoch 2/20
# 782/782 [==============================] - 148s 190ms/step - sparse_categorical_accuracy: 0.3429 - student_loss: 1.7783 - distillation_loss: 0.1799 - val_sparse_categorical_accuracy: 0.4697 - val_student_loss: 1.6699
# Epoch 3/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.3646 - student_loss: 1.7045 - distillation_loss: 0.1651 - val_sparse_categorical_accuracy: 0.4906 - val_student_loss: 1.6958
# Epoch 4/20
# 782/782 [==============================] - 148s 189ms/step - sparse_categorical_accuracy: 0.3833 - student_loss: 1.6551 - distillation_loss: 0.1557 - val_sparse_categorical_accuracy: 0.5045 - val_student_loss: 1.5434
# Epoch 5/20
# 782/782 [==============================] - 149s 191ms/step - sparse_categorical_accuracy: 0.4002 - student_loss: 1.6173 - distillation_loss: 0.1489 - val_sparse_categorical_accuracy: 0.5040 - val_student_loss: 1.4359
# Epoch 6/20
# 782/782 [==============================] - 149s 190ms/step - sparse_categorical_accuracy: 0.4143 - student_loss: 1.5879 - distillation_loss: 0.1446 - val_sparse_categorical_accuracy: 0.5322 - val_student_loss: 1.5515
# Epoch 7/20
# 782/782 [==============================] - 149s 191ms/step - sparse_categorical_accuracy: 0.4294 - student_loss: 1.5550 - distillation_loss: 0.1414 - val_sparse_categorical_accuracy: 0.5333 - val_student_loss: 1.3581
# Epoch 8/20
# 782/782 [==============================] - 149s 190ms/step - sparse_categorical_accuracy: 0.4309 - student_loss: 1.5345 - distillation_loss: 0.1379 - val_sparse_categorical_accuracy: 0.5418 - val_student_loss: 1.3319
# Epoch 9/20
# 782/782 [==============================] - 149s 191ms/step - sparse_categorical_accuracy: 0.4417 - student_loss: 1.5178 - distillation_loss: 0.1356 - val_sparse_categorical_accuracy: 0.5554 - val_student_loss: 1.2175
# Epoch 10/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.4402 - student_loss: 1.5099 - distillation_loss: 0.1342 - val_sparse_categorical_accuracy: 0.5692 - val_student_loss: 1.1340
# Epoch 11/20
# 782/782 [==============================] - 150s 191ms/step - sparse_categorical_accuracy: 0.4527 - student_loss: 1.4923 - distillation_loss: 0.1329 - val_sparse_categorical_accuracy: 0.5788 - val_student_loss: 1.1797
# Epoch 12/20
# 782/782 [==============================] - 150s 192ms/step - sparse_categorical_accuracy: 0.4636 - student_loss: 1.4629 - distillation_loss: 0.1292 - val_sparse_categorical_accuracy: 0.5740 - val_student_loss: 1.3347
# Epoch 13/20
# 782/782 [==============================] - 150s 191ms/step - sparse_categorical_accuracy: 0.4622 - student_loss: 1.4594 - distillation_loss: 0.1288 - val_sparse_categorical_accuracy: 0.5896 - val_student_loss: 1.2868
# Epoch 14/20
# 782/782 [==============================] - 150s 191ms/step - sparse_categorical_accuracy: 0.4712 - student_loss: 1.4462 - distillation_loss: 0.1265 - val_sparse_categorical_accuracy: 0.5873 - val_student_loss: 1.0939
# Epoch 15/20
# 782/782 [==============================] - 150s 192ms/step - sparse_categorical_accuracy: 0.4755 - student_loss: 1.4362 - distillation_loss: 0.1251 - val_sparse_categorical_accuracy: 0.5994 - val_student_loss: 1.0885
# Epoch 16/20
# 782/782 [==============================] - 150s 192ms/step - sparse_categorical_accuracy: 0.4781 - student_loss: 1.4306 - distillation_loss: 0.1249 - val_sparse_categorical_accuracy: 0.6004 - val_student_loss: 1.1609
# Epoch 17/20
# 782/782 [==============================] - 149s 191ms/step - sparse_categorical_accuracy: 0.4838 - student_loss: 1.4146 - distillation_loss: 0.1228 - val_sparse_categorical_accuracy: 0.6066 - val_student_loss: 1.2081
# Epoch 18/20
# 782/782 [==============================] - 150s 192ms/step - sparse_categorical_accuracy: 0.4856 - student_loss: 1.4098 - distillation_loss: 0.1227 - val_sparse_categorical_accuracy: 0.5991 - val_student_loss: 1.1230
# Epoch 19/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.4828 - student_loss: 1.4074 - distillation_loss: 0.1204 - val_sparse_categorical_accuracy: 0.5948 - val_student_loss: 1.2783
# Epoch 20/20
# 782/782 [==============================] - 150s 192ms/step - sparse_categorical_accuracy: 0.4848 - student_loss: 1.3983 - distillation_loss: 0.1206 - val_sparse_categorical_accuracy: 0.6079 - val_student_loss: 1.2674

# %%
# Evaluate student on test dataset
distiller.evaluate(x_test, y_test)
print(distiller.metrics_names)
# Out:
# 313/313 [==============================] - 2s 7ms/step - sparse_categorical_accuracy: 0.6079 - student_loss: 1.1356
# ['sparse_categorical_accuracy']

# %% [markdown]
# ### play with hyperparam for alpha

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)

distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.5,
    temperature=10,
)


# Distill teacher to student
history3b = distiller.fit(x_train, 
                         y_train, 
                         epochs=20,
                         batch_size=batch_size,
                         validation_data=(x_test, y_test), 
                         verbose=1)            




# Evaluate student on test dataset
distiller.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 152s 193ms/step - sparse_categorical_accuracy: 0.4859 - student_loss: 1.3742 - distillation_loss: 0.1311 - val_sparse_categorical_accuracy: 0.6084 - val_student_loss: 1.1553
# Epoch 2/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.4892 - student_loss: 1.3594 - distillation_loss: 0.1325 - val_sparse_categorical_accuracy: 0.6143 - val_student_loss: 0.9729
# Epoch 3/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.4968 - student_loss: 1.3463 - distillation_loss: 0.1330 - val_sparse_categorical_accuracy: 0.6194 - val_student_loss: 1.0238
# Epoch 4/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.4985 - student_loss: 1.3345 - distillation_loss: 0.1334 - val_sparse_categorical_accuracy: 0.6296 - val_student_loss: 0.9734
# Epoch 5/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.5003 - student_loss: 1.3298 - distillation_loss: 0.1336 - val_sparse_categorical_accuracy: 0.6183 - val_student_loss: 0.9631
# Epoch 6/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.4970 - student_loss: 1.3307 - distillation_loss: 0.1339 - val_sparse_categorical_accuracy: 0.6118 - val_student_loss: 0.9684
# Epoch 7/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5037 - student_loss: 1.3199 - distillation_loss: 0.1323 - val_sparse_categorical_accuracy: 0.6241 - val_student_loss: 1.0162
# Epoch 8/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.5031 - student_loss: 1.3183 - distillation_loss: 0.1334 - val_sparse_categorical_accuracy: 0.6255 - val_student_loss: 1.0648
# Epoch 9/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.5070 - student_loss: 1.3140 - distillation_loss: 0.1337 - val_sparse_categorical_accuracy: 0.6198 - val_student_loss: 1.0047
# Epoch 10/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5062 - student_loss: 1.3111 - distillation_loss: 0.1337 - val_sparse_categorical_accuracy: 0.6316 - val_student_loss: 1.0570
# Epoch 11/20
# 782/782 [==============================] - 154s 196ms/step - sparse_categorical_accuracy: 0.5114 - student_loss: 1.3080 - distillation_loss: 0.1341 - val_sparse_categorical_accuracy: 0.6333 - val_student_loss: 0.9807
# Epoch 12/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.5084 - student_loss: 1.3024 - distillation_loss: 0.1333 - val_sparse_categorical_accuracy: 0.6321 - val_student_loss: 0.9581
# Epoch 13/20
# 782/782 [==============================] - 151s 193ms/step - sparse_categorical_accuracy: 0.5082 - student_loss: 1.3034 - distillation_loss: 0.1332 - val_sparse_categorical_accuracy: 0.6207 - val_student_loss: 1.0800
# Epoch 14/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5136 - student_loss: 1.2900 - distillation_loss: 0.1314 - val_sparse_categorical_accuracy: 0.6373 - val_student_loss: 0.9915
# Epoch 15/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5120 - student_loss: 1.2950 - distillation_loss: 0.1316 - val_sparse_categorical_accuracy: 0.6210 - val_student_loss: 0.9739
# Epoch 16/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5113 - student_loss: 1.2884 - distillation_loss: 0.1321 - val_sparse_categorical_accuracy: 0.6361 - val_student_loss: 1.0372
# Epoch 17/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5145 - student_loss: 1.2871 - distillation_loss: 0.1311 - val_sparse_categorical_accuracy: 0.6381 - val_student_loss: 1.0096
# Epoch 18/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5140 - student_loss: 1.2861 - distillation_loss: 0.1316 - val_sparse_categorical_accuracy: 0.6423 - val_student_loss: 1.0322
# Epoch 19/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5160 - student_loss: 1.2790 - distillation_loss: 0.1317 - val_sparse_categorical_accuracy: 0.6366 - val_student_loss: 0.8813
# Epoch 20/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5169 - student_loss: 1.2868 - distillation_loss: 0.1323 - val_sparse_categorical_accuracy: 0.6267 - val_student_loss: 1.0080
# 313/313 [==============================] - 2s 7ms/step - sparse_categorical_accuracy: 0.6267 - student_loss: 1.0648
# [0.6266999840736389, 1.0080249309539795]

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)

distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.2,
    temperature=10,
)


# Distill teacher to student
history3c = distiller.fit(x_train, 
                         y_train, 
                         epochs=20,
                         batch_size=batch_size,
                         validation_data=(x_test, y_test), 
                         verbose=1)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 153s 194ms/step - sparse_categorical_accuracy: 0.5172 - student_loss: 1.2852 - distillation_loss: 0.1245 - val_sparse_categorical_accuracy: 0.6372 - val_student_loss: 0.9338
# Epoch 2/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5180 - student_loss: 1.2853 - distillation_loss: 0.1228 - val_sparse_categorical_accuracy: 0.6484 - val_student_loss: 0.9476
# Epoch 3/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5188 - student_loss: 1.2838 - distillation_loss: 0.1218 - val_sparse_categorical_accuracy: 0.6415 - val_student_loss: 0.8112
# Epoch 4/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5213 - student_loss: 1.2813 - distillation_loss: 0.1225 - val_sparse_categorical_accuracy: 0.6440 - val_student_loss: 1.0317
# Epoch 5/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.5195 - student_loss: 1.2801 - distillation_loss: 0.1209 - val_sparse_categorical_accuracy: 0.6397 - val_student_loss: 0.9549
# Epoch 6/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5199 - student_loss: 1.2841 - distillation_loss: 0.1209 - val_sparse_categorical_accuracy: 0.6510 - val_student_loss: 0.9800
# Epoch 7/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5200 - student_loss: 1.2823 - distillation_loss: 0.1196 - val_sparse_categorical_accuracy: 0.6395 - val_student_loss: 1.1210
# Epoch 8/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.5190 - student_loss: 1.2821 - distillation_loss: 0.1208 - val_sparse_categorical_accuracy: 0.6396 - val_student_loss: 0.9571
# Epoch 9/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.5248 - student_loss: 1.2745 - distillation_loss: 0.1198 - val_sparse_categorical_accuracy: 0.6335 - val_student_loss: 0.9476
# Epoch 10/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5197 - student_loss: 1.2766 - distillation_loss: 0.1195 - val_sparse_categorical_accuracy: 0.6401 - val_student_loss: 1.1094
# Epoch 11/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5232 - student_loss: 1.2705 - distillation_loss: 0.1198 - val_sparse_categorical_accuracy: 0.6432 - val_student_loss: 0.9720
# Epoch 12/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5247 - student_loss: 1.2744 - distillation_loss: 0.1188 - val_sparse_categorical_accuracy: 0.6450 - val_student_loss: 0.8544
# Epoch 13/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5240 - student_loss: 1.2724 - distillation_loss: 0.1191 - val_sparse_categorical_accuracy: 0.6438 - val_student_loss: 1.0485
# Epoch 14/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5229 - student_loss: 1.2684 - distillation_loss: 0.1184 - val_sparse_categorical_accuracy: 0.6400 - val_student_loss: 1.0952
# Epoch 15/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5242 - student_loss: 1.2665 - distillation_loss: 0.1184 - val_sparse_categorical_accuracy: 0.6432 - val_student_loss: 1.0378
# Epoch 16/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5259 - student_loss: 1.2699 - distillation_loss: 0.1176 - val_sparse_categorical_accuracy: 0.6397 - val_student_loss: 0.9203
# Epoch 17/20
# 782/782 [==============================] - 151s 194ms/step - sparse_categorical_accuracy: 0.5238 - student_loss: 1.2692 - distillation_loss: 0.1185 - val_sparse_categorical_accuracy: 0.6391 - val_student_loss: 0.9076
# Epoch 18/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5239 - student_loss: 1.2611 - distillation_loss: 0.1183 - val_sparse_categorical_accuracy: 0.6474 - val_student_loss: 0.7946
# Epoch 19/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5279 - student_loss: 1.2582 - distillation_loss: 0.1179 - val_sparse_categorical_accuracy: 0.6397 - val_student_loss: 0.9017
# Epoch 20/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5299 - student_loss: 1.2517 - distillation_loss: 0.1171 - val_sparse_categorical_accuracy: 0.6374 - val_student_loss: 0.9664
# 313/313 [==============================] - 2s 8ms/step - sparse_categorical_accuracy: 0.6374 - student_loss: 1.0421
# [0.6373999714851379, 0.9663770198822021]

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)

distiller.compile(
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.9,
    temperature=10,
)


# Distill teacher to student
history3d = distiller.fit(x_train, 
                         y_train, 
                         epochs=20,
                         batch_size=batch_size,
                         validation_data=(x_test, y_test), 
                         verbose=1)            




# Evaluate student on test dataset
distiller.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 169s 215ms/step - sparse_categorical_accuracy: 0.5326 - student_loss: 1.2255 - distillation_loss: 0.1339 - val_sparse_categorical_accuracy: 0.6533 - val_student_loss: 0.9025
# Epoch 2/20
# 782/782 [==============================] - 154s 197ms/step - sparse_categorical_accuracy: 0.5353 - student_loss: 1.2246 - distillation_loss: 0.1351 - val_sparse_categorical_accuracy: 0.6598 - val_student_loss: 0.9657
# Epoch 3/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5338 - student_loss: 1.2256 - distillation_loss: 0.1344 - val_sparse_categorical_accuracy: 0.6505 - val_student_loss: 0.9998
# Epoch 4/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5352 - student_loss: 1.2270 - distillation_loss: 0.1352 - val_sparse_categorical_accuracy: 0.6494 - val_student_loss: 1.1820
# Epoch 5/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5367 - student_loss: 1.2196 - distillation_loss: 0.1353 - val_sparse_categorical_accuracy: 0.6520 - val_student_loss: 0.9565
# Epoch 6/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5378 - student_loss: 1.2152 - distillation_loss: 0.1349 - val_sparse_categorical_accuracy: 0.6536 - val_student_loss: 0.9795
# Epoch 7/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5362 - student_loss: 1.2202 - distillation_loss: 0.1361 - val_sparse_categorical_accuracy: 0.6597 - val_student_loss: 0.9442
# Epoch 8/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5393 - student_loss: 1.2144 - distillation_loss: 0.1353 - val_sparse_categorical_accuracy: 0.6605 - val_student_loss: 0.9407
# Epoch 9/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5390 - student_loss: 1.2211 - distillation_loss: 0.1366 - val_sparse_categorical_accuracy: 0.6656 - val_student_loss: 1.1089
# Epoch 10/20
# 782/782 [==============================] - 152s 194ms/step - sparse_categorical_accuracy: 0.5395 - student_loss: 1.2138 - distillation_loss: 0.1356 - val_sparse_categorical_accuracy: 0.6681 - val_student_loss: 1.0058
# Epoch 11/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5428 - student_loss: 1.2056 - distillation_loss: 0.1349 - val_sparse_categorical_accuracy: 0.6592 - val_student_loss: 0.9776
# Epoch 12/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5378 - student_loss: 1.2171 - distillation_loss: 0.1362 - val_sparse_categorical_accuracy: 0.6619 - val_student_loss: 0.9600
# Epoch 13/20
# 782/782 [==============================] - 152s 195ms/step - sparse_categorical_accuracy: 0.5403 - student_loss: 1.2090 - distillation_loss: 0.1366 - val_sparse_categorical_accuracy: 0.6645 - val_student_loss: 1.0740
# Epoch 14/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5398 - student_loss: 1.2119 - distillation_loss: 0.1364 - val_sparse_categorical_accuracy: 0.6387 - val_student_loss: 0.9599
# Epoch 15/20
# 782/782 [==============================] - 153s 195ms/step - sparse_categorical_accuracy: 0.5406 - student_loss: 1.2096 - distillation_loss: 0.1362 - val_sparse_categorical_accuracy: 0.6684 - val_student_loss: 1.1789
# Epoch 16/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5425 - student_loss: 1.2102 - distillation_loss: 0.1368 - val_sparse_categorical_accuracy: 0.6708 - val_student_loss: 0.9386
# Epoch 17/20
# 782/782 [==============================] - 154s 196ms/step - sparse_categorical_accuracy: 0.5449 - student_loss: 1.2036 - distillation_loss: 0.1352 - val_sparse_categorical_accuracy: 0.6623 - val_student_loss: 1.0014
# Epoch 18/20
# 782/782 [==============================] - 154s 197ms/step - sparse_categorical_accuracy: 0.5419 - student_loss: 1.1979 - distillation_loss: 0.1355 - val_sparse_categorical_accuracy: 0.6700 - val_student_loss: 1.0610
# Epoch 19/20
# 782/782 [==============================] - 154s 196ms/step - sparse_categorical_accuracy: 0.5450 - student_loss: 1.2016 - distillation_loss: 0.1361 - val_sparse_categorical_accuracy: 0.6653 - val_student_loss: 0.9537
# Epoch 20/20
# 782/782 [==============================] - 153s 196ms/step - sparse_categorical_accuracy: 0.5432 - student_loss: 1.2010 - distillation_loss: 0.1361 - val_sparse_categorical_accuracy: 0.6686 - val_student_loss: 0.9546
# 313/313 [==============================] - 3s 8ms/step - sparse_categorical_accuracy: 0.6686 - student_loss: 0.9826
# [0.6686000227928162, 0.9546219706535339]

# %% [markdown]
# ### effect of alpha:
#
# alpha values taken were 0.1, 0.2. 0.5, 0.9
#
# loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss
#
# higher alpha suggests high student loss effect and low distilation effect.
#
#
# i.e. low alpha should give better results, since it can use distillation better.
#
# so far that is not so evident...
